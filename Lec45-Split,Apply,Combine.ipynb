# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
dframe_wine = pd.read_csv('C:\\Users\\v-satnai\\Downloads\\winequality-red.csv',sep=';')

dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
def ranker(df):
    df['alc_content_rank'] = np.arange(len(df)+1)
    return df

# %%
dframe_wine.sort_values('alcohol',ascending=False,inplace=True)

# %%
dframe_wine1=dframe_wine.groupby('quality')

# %%
dframe_wine1=dframe_wine.groupby('quality').apply(ranker)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-9d99f9b10d85> in <module>()
# ----> 1 dframe_wine1=dframe_wine.groupby('quality').apply(ranker)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in apply(self, func, *args, **kwargs)
#     714         # ignore SettingWithCopy here in case the user mutates
#     715         with option_context('mode.chained_assignment', None):
# --> 716             return self._python_apply_general(f)
#     717
#     718     def _python_apply_general(self, f):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in _python_apply_general(self, f)
#     718     def _python_apply_general(self, f):
#     719         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 720                                                    self.axis)
#     721
# ...

# %%
dframe_wine.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652            15.9              0.36         0.65             7.5      0.096
# 588             5.0              0.42         0.24             2.0      0.060
# 142             5.2              0.34         0.00             1.8      0.050
# 144             5.2              0.34         0.00             1.8      0.050
# 1270            5.0              0.38         0.01             1.6      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 652                  22.0                  71.0  0.99760  2.98       0.84
# 588                  19.0                  50.0  0.99170  3.72       0.74
# 142                  27.0                  63.0  0.99160  3.68       0.79
# 144                  27.0                  63.0  0.99160  3.68       0.79
# 1270                 26.0                  60.0  0.99084  3.70       0.75
#
#       alcohol  quality
# 652      14.9        5
# ...

# %%
num_of_qual=dframe_wine['quality'].value_counts()
num_of_qual
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
dframe_wine[dframe_wine.alcohol > 2].sort_values('quality').head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 517            10.4             0.610         0.49             2.1      0.200
# 832            10.4             0.440         0.42             1.5      0.145
# 1374            6.8             0.815         0.00             1.2      0.267
# 1299            7.6             1.580         0.00             2.1      0.137
# 1505            6.7             0.760         0.02             1.8      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 517                   5.0                  16.0  0.99940  3.16       0.63
# 832                  34.0                  48.0  0.99832  3.38       0.86
# 1374                 16.0                  29.0  0.99471  3.32       0.51
# 1299                  5.0                   9.0  0.99476  3.50       0.40
# 1505                  6.0                  12.0  0.99600  3.55       0.63
#
#       alcohol  quality
# 517      8.40        3
# ...

# %%
dframe_wine[dframe_wine.alc_content_rank == 1].head(len(num_of_qual))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-23750e12c840> in <module>()
# ----> 1 dframe_wine[dframe_wine.alc_content_rank == 1].head(len(num_of_qual))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'alc_content_rank'
