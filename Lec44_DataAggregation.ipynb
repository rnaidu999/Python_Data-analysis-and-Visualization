# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
url='https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/'

# %%
dframe_wine = pd.read_csv('C:\\Users\\v-satnai\\Downloads\\winequality-red.csv',sep=';')

# %%
dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# Determined avg alcohol content of the wine
dframe_wine['alcohol'].mean()
# Out:
# 10.422983114446502

# %%
# Show entire DataFrame
#dframe_wine

# %%
def max_to_min(arr):
    return arr(max)-arr(min)

# %%
wino=dframe_wine.groupby('quality')

wino.describe().T
# Out:
# quality                             3           4           5           6  \
# alcohol              count  10.000000   53.000000  681.000000  638.000000
#                      mean    9.955000   10.265094    9.899706   10.629519
#                      std     0.818009    0.934776    0.736521    1.049639
#                      min     8.400000    9.000000    8.500000    8.400000
#                      25%     9.725000    9.600000    9.400000    9.800000
#                      50%     9.925000   10.000000    9.700000   10.500000
#                      75%    10.575000   11.000000   10.200000   11.300000
#                      max    11.000000   13.100000   14.900000   14.000000
# chlorides            count  10.000000   53.000000  681.000000  638.000000
#                      mean    0.122500    0.090679    0.092736    0.084956
#                      std     0.066241    0.076192    0.053707    0.039563
#                      min     0.061000    0.045000    0.039000    0.034000
#                      25%     0.079000    0.067000    0.074000    0.068250
#                      50%     0.090500    0.080000    0.081000    0.078000
#                      75%     0.143000    0.089000    0.094000    0.088000
#                      max     0.267000    0.610000    0.611000    0.415000
# citric acid          count  10.000000   53.000000  681.000000  638.000000
#                      mean    0.171000    0.174151    0.243686    0.273824
#                      std     0.250664    0.201030    0.180003    0.195108
#                      min     0.000000    0.000000    0.000000    0.000000
#                      25%     0.005000    0.030000    0.090000    0.090000
#                      50%     0.035000    0.090000    0.230000    0.260000
#                      75%     0.327500    0.270000    0.360000    0.430000
#                      max     0.660000    1.000000    0.790000    0.780000
# density              count  10.000000   53.000000  681.000000  638.000000
#                      mean    0.997464    0.996542    0.997104    0.996615
#                      std     0.002002    0.001575    0.001589    0.002000
#                      min     0.994710    0.993400    0.992560    0.990070
#                      25%     0.996150    0.995650    0.996200    0.995402
#                      50%     0.997565    0.996500    0.997000    0.996560
# ...                               ...         ...         ...         ...
# residual sugar       std     1.401596    1.789436    1.359753    1.441576
#                      min     1.200000    1.300000    1.200000    0.900000
#                      25%     1.875000    1.900000    1.900000    1.900000
#                      50%     2.100000    2.100000    2.200000    2.200000
#                      75%     3.100000    2.800000    2.600000    2.500000
#                      max     5.700000   12.900000   15.500000   15.400000
# sulphates            count  10.000000   53.000000  681.000000  638.000000
#                      mean    0.570000    0.596415    0.620969    0.675329
#                      std     0.122020    0.239391    0.171062    0.158650
#                      min     0.400000    0.330000    0.370000    0.400000
#                      25%     0.512500    0.490000    0.530000    0.580000
#                      50%     0.545000    0.560000    0.580000    0.640000
#                      75%     0.615000    0.600000    0.660000    0.750000
#                      max     0.860000    2.000000    1.980000    1.950000
# total sulfur dioxide count  10.000000   53.000000  681.000000  638.000000
#                      mean   24.900000   36.245283   56.513950   40.869906
#                      std    16.828877   27.583374   36.993116   25.038250
#                      min     9.000000    7.000000    6.000000    6.000000
#                      25%    12.500000   14.000000   26.000000   23.000000
#                      50%    15.000000   26.000000   47.000000   35.000000
#                      75%    42.500000   49.000000   84.000000   54.000000
#                      max    49.000000  119.000000  155.000000  165.000000
# volatile acidity     count  10.000000   53.000000  681.000000  638.000000
#                      mean    0.884500    0.693962    0.577041    0.497484
#                      std     0.331256    0.220110    0.164801    0.160962
#                      min     0.440000    0.230000    0.180000    0.160000
#                      25%     0.647500    0.530000    0.460000    0.380000
#                      50%     0.845000    0.670000    0.580000    0.490000
#                      75%     1.010000    0.870000    0.670000    0.600000
#                      max     1.580000    1.130000    1.330000    1.040000
#
# quality                              7          8
# alcohol              count  199.000000  18.000000
#                      mean    11.465913  12.094444
#                      std      0.961933   1.224011
#                      min      9.200000   9.800000
#                      25%     10.800000  11.325000
#                      50%     11.500000  12.150000
#                      75%     12.100000  12.875000
#                      max     14.000000  14.000000
# chlorides            count  199.000000  18.000000
#                      mean     0.076588   0.068444
#                      std      0.029456   0.011678
#                      min      0.012000   0.044000
#                      25%      0.062000   0.062000
#                      50%      0.073000   0.070500
#                      75%      0.087000   0.075500
#                      max      0.358000   0.086000
# citric acid          count  199.000000  18.000000
#                      mean     0.375176   0.391111
#                      std      0.194432   0.199526
#                      min      0.000000   0.030000
#                      25%      0.305000   0.302500
#                      50%      0.400000   0.420000
#                      75%      0.490000   0.530000
#                      max      0.760000   0.720000
# density              count  199.000000  18.000000
#                      mean     0.996104   0.995212
#                      std      0.002176   0.002378
#                      min      0.990640   0.990800
#                      25%      0.994765   0.994175
#                      50%      0.995770   0.994940
# ...                                ...        ...
# residual sugar       std      1.371509   1.295038
#                      min      1.200000   1.400000
#                      25%      2.000000   1.800000
#                      50%      2.300000   2.100000
#                      75%      2.750000   2.600000
#                      max      8.900000   6.400000
# sulphates            count  199.000000  18.000000
#                      mean     0.741256   0.767778
#                      std      0.135639   0.115379
#                      min      0.390000   0.630000
#                      25%      0.650000   0.690000
#                      50%      0.740000   0.740000
#                      75%      0.830000   0.820000
#                      max      1.360000   1.100000
# total sulfur dioxide count  199.000000  18.000000
#                      mean    35.020101  33.444444
#                      std     33.191206  25.433240
#                      min      7.000000  12.000000
#                      25%     17.500000  16.000000
#                      50%     27.000000  21.500000
#                      75%     43.000000  43.000000
#                      max    289.000000  88.000000
# volatile acidity     count  199.000000  18.000000
#                      mean     0.403920   0.423333
#                      std      0.145224   0.144914
#                      min      0.120000   0.260000
#                      25%      0.300000   0.335000
#                      50%      0.370000   0.370000
#                      75%      0.485000   0.472500
#                      max      0.915000   0.850000
#
# [88 rows x 6 columns]

# %%
def max_to_min(arr):
    return arr(max)-arr(min)
wino.agg(max_to_min)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    3482                     result = self._aggregate_multiple_funcs(
# -> 3483                         [arg], _level=_level, _axis=self.axis)
#    3484                     result.columns = Index(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     690         if not len(results):
# --> 691             raise ValueError("no results")
#     692
#
# ValueError: no results
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in _aggregate_generic(self, func, *args, **kwargs)
#    3508                 for name, data in self:
# -> 3509                     result[name] = self._try_cast(func(data, *args, **kwargs),
#    3510                                                   data)
#
# <ipython-input-46-cb1b2dbdcbd6> in max_to_min(arr)
#       1 def max_to_min(arr):
# ----> 2     return arr(max)-arr(min)
#       3 wino.agg(max_to_min)
#
# TypeError: 'DataFrame' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-cb1b2dbdcbd6> in <module>()
#       1 def max_to_min(arr):
#       2     return arr(max)-arr(min)
# ----> 3 wino.agg(max_to_min)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4034         versionadded=''))
#    4035     def aggregate(self, arg, *args, **kwargs):
# -> 4036         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4037
#    4038     agg = aggregate
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    3486                         name=self._selected_obj.columns.name)
#    3487                 except:
# -> 3488                     result = self._aggregate_generic(arg, *args, **kwargs)
#    3489
#    3490         if not self.as_index:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in _aggregate_generic(self, func, *args, **kwargs)
#    3510                                                   data)
#    3511             except Exception:
# -> 3512                 return self._aggregate_item_by_item(func, *args, **kwargs)
#    3513         else:
#    3514             for name in self.indices:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in _aggregate_item_by_item(self, func, *args, **kwargs)
#    3554             # GH6337
#    3555             if not len(result_columns) and errors is not None:
# -> 3556                 raise errors
#    3557
#    3558         return DataFrame(result, columns=result_columns)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in _aggregate_item_by_item(self, func, *args, **kwargs)
#    3539                                      grouper=self.grouper)
#    3540                 result[item] = self._try_cast(
# -> 3541                     colg.aggregate(func, *args, **kwargs), data)
#    3542             except ValueError:
#    3543                 cannot_agg.append(item)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    2883                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    2884             except Exception:
# -> 2885                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#    2886
#    2887             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby.py in _aggregate_named(self, func, *args, **kwargs)
#    3013         for name, group in self:
#    3014             group.name = name
# -> 3015             output = func(group, *args, **kwargs)
#    3016             if isinstance(output, (Series, Index, np.ndarray)):
#    3017                 raise Exception('Must produce aggregated value')
#
# <ipython-input-46-cb1b2dbdcbd6> in max_to_min(arr)
#       1 def max_to_min(arr):
# ----> 2     return arr(max)-arr(min)
#       3 wino.agg(max_to_min)
#
# TypeError: 'Series' object is not callable

# %%
wino.agg('mean')
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# 8         0.068444            13.277778             33.444444  0.995212
#
#                pH  sulphates    alcohol
# quality
# 3        3.398000   0.570000   9.955000
# 4        3.381509   0.596415  10.265094
# 5        3.304949   0.620969   9.899706
# 6        3.318072   0.675329  10.629519
# 7        3.290754   0.741256  11.465913
# 8        3.267222   0.767778  12.094444

# %%
dframe_wine.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
dframe_wine['Qul/Alc Ratio']=dframe_wine['quality']/dframe_wine['alcohol']

# %%
dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Qul/Alc Ratio
# 0      9.4        5       0.531915
# 1      9.8        5       0.510204
# 2      9.8        5       0.510204
# 3      9.8        6       0.612245
# 4      9.4        5       0.531915

# %%
dframe_wine.pivot_table(index=['quality'])
# Out:
#          Qul/Alc Ratio    alcohol  chlorides  citric acid   density  \
# quality
# 3             0.303286   9.955000   0.122500     0.171000  0.997464
# 4             0.392724  10.265094   0.090679     0.174151  0.996542
# 5             0.507573   9.899706   0.092736     0.243686  0.997104
# 6             0.569801  10.629519   0.084956     0.273824  0.996615
# 7             0.614855  11.465913   0.076588     0.375176  0.996104
# 8             0.668146  12.094444   0.068444     0.391111  0.995212
#
#          fixed acidity  free sulfur dioxide        pH  residual sugar  \
# quality
# 3             8.360000            11.000000  3.398000        2.635000
# 4             7.779245            12.264151  3.381509        2.694340
# 5             8.167254            16.983847  3.304949        2.528855
# 6             8.347179            15.711599  3.318072        2.477194
# 7             8.872362            14.045226  3.290754        2.720603
# 8             8.566667            13.277778  3.267222        2.577778
#
#          sulphates  total sulfur dioxide  volatile acidity
# quality
# 3         0.570000             24.900000          0.884500
# 4         0.596415             36.245283          0.693962
# 5         0.620969             56.513950          0.577041
# 6         0.675329             40.869906          0.497484
# 7         0.741256             35.020101          0.403920
# 8         0.767778             33.444444          0.423333

# %%
# %matplotlib inline

# %%
dframe_wine.plot(kind='scatter',x='quality',y='alcohol')
